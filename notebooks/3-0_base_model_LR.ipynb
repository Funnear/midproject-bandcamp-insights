# %%
# Basic libraries
import pandas as pd

# Project libraries
# set path to local modules and submodules
import sys, os
sys.path.append(os.path.abspath("src")) # add src folder to path
# import local modules and submodules
from data_ravers_utils.kaggle_loader import download_kaggle_dataset
from data_ravers_utils.file_handler import *
import data_ravers_utils.eda_utils as eda
import data_ravers_utils.model_linear_regressor as lr

# Settings
pd.set_option('display.max_columns', None) # display all columns
import warnings
warnings.filterwarnings('ignore') # ignore warnings


# Logging
import logging
# setup logging level
logging.getLogger().setLevel(logging.DEBUG)

# %% [markdown]
# # Prepare raw data for training base model

# %%
df_filename = 'bandcamp-sales-v0-raw'
data = read_df_pickle(df_filename)
df = data.copy()
df.head(5)
# Out:
#                                                  _id  \
# 0  1599688803.5175&//girlbanddublin.bandcamp.com/...
# 1  1599688805.27838&//maharettarecords.bandcamp.c...
# 2  1599688805.90646&//maharettarecords.bandcamp.c...
# 3  1599688806.94234&//alicesitski.bandcamp.com/al...
# 4  1599688809.07942&//linguaignota.bandcamp.com/t...
#
#                                        art_url item_type      utc_date  \
# 0  https://f4.bcbits.com/img/a0206405257_7.jpg         a  1.599689e+09
# 1  https://f4.bcbits.com/img/a2984241552_7.jpg         a  1.599689e+09
# 2  https://f4.bcbits.com/img/a3320494770_7.jpg         a  1.599689e+09
# 3  https://f4.bcbits.com/img/0020476345_37.jpg         p  1.599689e+09
# 4  https://f4.bcbits.com/img/a3428873396_7.jpg         t  1.599689e+09
#
#   country_code track_album_slug_text         country slug_type  \
# 0           gb                   NaN  United Kingdom         a
# 1           fi                   NaN         Finland         a
# 2           fi                   NaN         Finland         a
# 3           gb                   NaN  United Kingdom         a
# 4           us                   NaN   United States         t
#
#   amount_paid_fmt  item_price                  item_description        art_id  \
# 0           $9.99        9.99              Live at Vicar Street  2.064053e+08
# 1              £1        1.00                          Neurogen  2.984242e+09
# 2              £3        3.00             The Last Snare Bender  3.320495e+09
# 3          €10.50       10.50      Limited Edition Compact Disc           NaN
# 4              $1        1.00  O Ruthless Great Divine Director  3.428873e+09
#
#                                                  url  amount_paid  releases  \
# 0  //girlbanddublin.bandcamp.com/album/live-at-vi...         9.99       NaN
# 1     //maharettarecords.bandcamp.com/album/neurogen         1.00       NaN
# 2  //maharettarecords.bandcamp.com/album/the-last...         3.00       NaN
# 3    //alicesitski.bandcamp.com/album/white-noise-tv        10.50       NaN
# 4  //linguaignota.bandcamp.com/track/o-ruthless-g...         1.00       NaN
#
#       artist_name currency     album_title  amount_paid_usd  package_image_id  \
# 0       Girl Band      USD             NaN             9.99               NaN
# 1           Jirah      GBP             NaN             1.30               NaN
# 2          D-Ther      GBP             NaN             3.90               NaN
# 3  WHITE NOISE TV      EUR  WHITE NOISE TV            12.39        20476345.0
# 4   LINGUA IGNOTA      USD             NaN             1.00               NaN
#
#   amount_over_fmt item_slug  addl_count
# 0             NaN       NaN         NaN
# 1             NaN       NaN         NaN
# 2             NaN       NaN         NaN
# 3             NaN       NaN         NaN
# 4             NaN       NaN         NaN

# %%
target_variable_main = 'amount_paid_usd'

# %%
df[target_variable_main].describe()
# Out:
# count    1000000.000000
# mean           8.931315
# std           12.490078
# min            0.200000
# 25%            2.000000
# 50%            6.000000
# 75%           11.630000
# max         1286.260000
# Name: amount_paid_usd, dtype: float64

# %%
target_variable_extra = "amount_over_fmt"

# Can I use the data for prediction?

df["amount_over_fmt"].apply(type).value_counts()
# Out:
# amount_over_fmt
# <class 'float'>    880867
# <class 'str'>      119133
# Name: count, dtype: int64

# %%
# getting all numerical columns
numeric_columns = eda.get_numerical_columns(df)
numeric_columns
# Out:
# ['utc_date',
#  'item_price',
#  'art_id',
#  'amount_paid',
#  'releases',
#  'amount_paid_usd',
#  'package_image_id',
#  'addl_count']

# %%
# Fill NaN values with 0
df.fillna(0, inplace=True)

# %% [markdown]
# # Heads-on approach to hyperparameters testing

# %% [markdown]
# ## For the main target

# %%
logging.getLogger().setLevel(logging.INFO)

# Define different subsets of features
feature_subsets = {
    "numeric_features_raw": numeric_columns
}

# Define test sizes to experiment with
test_sizes = [0.1, 0.2, 0.3, 0.4]

# Define different random_state values for variability
random_states = [15, 42, 100]

test_results_df = lr.linear_regression_combo_test(df, feature_subsets, target_variable_main, test_sizes, random_states)

test_results_df
# Out:
#                                      test_size  random_state   R2  MAE  \
# LR_numeric_features_raw_ts0.1_rs15         0.1          15.0  1.0  0.0
# LR_numeric_features_raw_ts0.1_rs42         0.1          42.0  1.0  0.0
# LR_numeric_features_raw_ts0.1_rs100        0.1         100.0  1.0  0.0
# LR_numeric_features_raw_ts0.2_rs15         0.2          15.0  1.0  0.0
# LR_numeric_features_raw_ts0.2_rs42         0.2          42.0  1.0  0.0
# LR_numeric_features_raw_ts0.2_rs100        0.2         100.0  1.0  0.0
# LR_numeric_features_raw_ts0.3_rs15         0.3          15.0  1.0  0.0
# LR_numeric_features_raw_ts0.3_rs42         0.3          42.0  1.0  0.0
# LR_numeric_features_raw_ts0.3_rs100        0.3         100.0  1.0  0.0
# LR_numeric_features_raw_ts0.4_rs15         0.4          15.0  1.0  0.0
# LR_numeric_features_raw_ts0.4_rs42         0.4          42.0  1.0  0.0
# LR_numeric_features_raw_ts0.4_rs100        0.4         100.0  1.0  0.0
#
#                                        RMSE  MSE
# LR_numeric_features_raw_ts0.1_rs15   0.0001  0.0
# LR_numeric_features_raw_ts0.1_rs42   0.0001  0.0
# LR_numeric_features_raw_ts0.1_rs100  0.0001  0.0
# LR_numeric_features_raw_ts0.2_rs15   0.0000  0.0
# LR_numeric_features_raw_ts0.2_rs42   0.0000  0.0
# LR_numeric_features_raw_ts0.2_rs100  0.0000  0.0
# LR_numeric_features_raw_ts0.3_rs15   0.0000  0.0
# LR_numeric_features_raw_ts0.3_rs42   0.0000  0.0
# LR_numeric_features_raw_ts0.3_rs100  0.0000  0.0
# LR_numeric_features_raw_ts0.4_rs15   0.0000  0.0
# LR_numeric_features_raw_ts0.4_rs42   0.0000  0.0
# LR_numeric_features_raw_ts0.4_rs100  0.0000  0.0

# %% [markdown]
# ### The best model for the main target

# %%
base_linear_regression_model, dict_test_results = lr.linear_regression_control(df, numeric_columns, target_variable_main, test_size=0.1, random_state=15)

for key, value in dict_test_results.items():
    print(f"{key}: {value}")
# Out:
# test_size: 0.1
# random_state: 15
# R2: 0.9999999999582607
# MAE: 1.7139541815768866e-05
# RMSE: 7.079246501129246e-05
# MSE: 5.011573102375068e-09

# %% [markdown]
# # Interpretation of results

# %% [markdown]
# - Direct predictors
# - Imbalanced dataset
#
# Extra target is not prepaired for modeling because it contains string values.
